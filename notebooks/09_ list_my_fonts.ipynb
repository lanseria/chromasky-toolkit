# %%
# list_my_fonts.py

import matplotlib.font_manager as fm
from collections import defaultdict

def list_all_system_fonts():
    """
    使用 matplotlib 的字体管理器，清晰地列出当前系统上所有可用的字体。
    """
    print("=" * 70)
    print(">>> 正在扫描您系统中的所有可用字体...")
    print("=" * 70)

    # fm.fontManager.ttflist 包含了所有 matplotlib 扫描到的字体
    all_fonts = fm.fontManager.ttflist
    
    if not all_fonts:
        print("\n❌ 错误：Matplotlib 未能找到任何字体。")
        print("   请尝试删除 matplotlib 的字体缓存文件并重启程序。")
        print(f"   缓存文件通常位于: {fm.get_cachedir()}")
        return

    # 为了更清晰的列表，我们按字体族名称（family name）分组
    font_families = defaultdict(list)
    for font_entry in all_fonts:
        # font_entry.name 是字体的“家族名称”
        font_families[font_entry.name].append(font_entry.fname)

    print(f"\n✅ 扫描完成！共找到 {len(all_fonts)} 个字体文件，归属于 {len(font_families)} 个字体族。")
    print("\n" + "=" * 70)
    print(">>> 以下是按字体族（Font Family）分类的详细列表：")
    print("=" * 70)

    # 按字母顺序排序并打印
    for family_name in sorted(font_families.keys()):
        print(f"\n▶ 字体族: {family_name}")
        # 只显示最多5个文件路径，避免列表过长
        for i, file_path in enumerate(font_families[family_name][:5]):
            print(f"  - 文件: {file_path}")
        if len(font_families[family_name]) > 5:
            print(f"  ... (等 {len(font_families[family_name]) - 5} 个文件)")

    print("\n" + "=" * 70)
    print(">>> 扫描结束。")
    print(">>> 请从此列表中寻找您系统上安装的中文字体，例如：")
    print("    - Windows: 'SimSun', 'SimHei', 'Microsoft YaHei', 'DengXian'")
    print("    - macOS: 'PingFang SC', 'Hiragino Sans GB', 'STHeiti'")
    print("    - Linux: 'Noto Sans CJK SC', 'WenQuanYi Micro Hei'")
    print("=" * 70)


if __name__ == "__main__":
    list_all_system_fonts()
# Out:
# ======================================================================
# >>> 正在扫描您系统中的所有可用字体...
# ======================================================================
#
# ✅ 扫描完成！共找到 571 个字体文件，归属于 385 个字体族。
#
# ======================================================================
# >>> 以下是按字体族（Font Family）分类的详细列表：
# ======================================================================
#
# ▶ 字体族: .Aqua Kana
#   - 文件: /System/Library/Fonts/AquaKana.ttc
#
# ▶ 字体族: .CJK Symbols Fallback HK
#   - 文件: /System/Library/Fonts/CJKSymbolsFallback.ttc
#
# ▶ 字体族: .DecoType Nastaleeq Urdu UI
#   - 文件: /System/Library/Fonts/DecoTypeNastaleeqUrdu.ttc
#
# ▶ 字体族: .Keyboard
#   - 文件: /System/Library/Fonts/Keyboard.ttf
#
# ▶ 字体族: .New York
#   - 文件: /System/Library/Fonts/NewYork.ttf
#   - 文件: /System/Library/Fonts/NewYorkItalic.ttf
#
# ▶ 字体族: .SF Arabic
#   - 文件: /System/Library/Fonts/SFArabic.ttf
#
# ▶ 字体族: .SF Arabic Rounded
#   - 文件: /System/Library/Fonts/SFArabicRounded.ttf
#
# ▶ 字体族: .SF Armenian
#   - 文件: /System/Library/Fonts/SFArmenian.ttf
#
# ▶ 字体族: .SF Armenian Rounded
#   - 文件: /System/Library/Fonts/SFArmenianRounded.ttf
#
# ▶ 字体族: .SF Camera
#   - 文件: /System/Library/Fonts/SFCamera.ttf
#
# ▶ 字体族: .SF Compact
#   - 文件: /System/Library/Fonts/SFCompactItalic.ttf
#   - 文件: /System/Library/Fonts/SFCompact.ttf
#
# ▶ 字体族: .SF Compact Rounded
#   - 文件: /System/Library/Fonts/SFCompactRounded.ttf
#
# ▶ 字体族: .SF Georgian
#   - 文件: /System/Library/Fonts/SFGeorgian.ttf
#
# ▶ 字体族: .SF Georgian Rounded
#   - 文件: /System/Library/Fonts/SFGeorgianRounded.ttf
#
# ▶ 字体族: .SF Hebrew
#   - 文件: /System/Library/Fonts/SFHebrew.ttf
#
# ▶ 字体族: .SF Hebrew Rounded
#   - 文件: /System/Library/Fonts/SFHebrewRounded.ttf
#
# ▶ 字体族: .SF NS Mono
#   - 文件: /System/Library/Fonts/SFNSMonoItalic.ttf
#   - 文件: /System/Library/Fonts/SFNSMono.ttf
#
# ▶ 字体族: .SF NS Rounded
#   - 文件: /System/Library/Fonts/SFNSRounded.ttf
#
# ▶ 字体族: .SF Soft Numeric
#   - 文件: /System/Library/Fonts/ADTNumeric.ttc
#
# ▶ 字体族: .ThonburiUI
#   - 文件: /System/Library/Fonts/ThonburiUI.ttc
#
# ▶ 字体族: Academy Engraved LET
#   - 文件: /System/Library/Fonts/Supplemental/Academy Engraved LET Fonts.ttf
#
# ▶ 字体族: Al Bayan
#   - 文件: /System/Library/Fonts/Supplemental/AlBayan.ttc
#
# ▶ 字体族: Al Nile
#   - 文件: /System/Library/Fonts/Supplemental/Al Nile.ttc
#
# ▶ 字体族: Al Tarikh
#   - 文件: /System/Library/Fonts/Supplemental/Al Tarikh.ttc
#
# ▶ 字体族: American Typewriter
#   - 文件: /System/Library/Fonts/Supplemental/AmericanTypewriter.ttc
#
# ▶ 字体族: Andale Mono
#   - 文件: /System/Library/Fonts/Supplemental/Andale Mono.ttf
#
# ▶ 字体族: Apple Braille
#   - 文件: /System/Library/Fonts/Apple Braille Outline 8 Dot.ttf
#   - 文件: /System/Library/Fonts/Apple Braille.ttf
#   - 文件: /System/Library/Fonts/Apple Braille Outline 6 Dot.ttf
#   - 文件: /System/Library/Fonts/Apple Braille Pinpoint 6 Dot.ttf
#   - 文件: /System/Library/Fonts/Apple Braille Pinpoint 8 Dot.ttf
#
# ▶ 字体族: Apple Chancery
#   - 文件: /System/Library/Fonts/Supplemental/Apple Chancery.ttf
#
# ▶ 字体族: Apple LiGothic
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/de97612eef4e3cf8ee8e5c0ebd6fd879bbecd23a.asset/AssetData/AppleLiGothic-Medium.ttf
#
# ▶ 字体族: Apple LiSung
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/2ae839cbaa0ff60fe6a1d8921a77c81adcec0646.asset/AssetData/AppleLiSung-Light.ttf
#
# ▶ 字体族: Apple SD Gothic Neo
#   - 文件: /System/Library/Fonts/AppleSDGothicNeo.ttc
#
# ▶ 字体族: Apple Symbols
#   - 文件: /System/Library/Fonts/Apple Symbols.ttf
#
# ▶ 字体族: AppleGothic
#   - 文件: /System/Library/Fonts/Supplemental/AppleGothic.ttf
#
# ▶ 字体族: AppleMyungjo
#   - 文件: /System/Library/Fonts/Supplemental/AppleMyungjo.ttf
#
# ▶ 字体族: Arial
#   - 文件: /System/Library/Fonts/Supplemental/Arial Bold Italic.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Arial.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Arial Italic.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Arial Bold.ttf
#
# ▶ 字体族: Arial Black
#   - 文件: /System/Library/Fonts/Supplemental/Arial Black.ttf
#
# ▶ 字体族: Arial Hebrew
#   - 文件: /System/Library/Fonts/ArialHB.ttc
#
# ▶ 字体族: Arial Narrow
#   - 文件: /System/Library/Fonts/Supplemental/Arial Narrow.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Arial Narrow Bold.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Arial Narrow Bold Italic.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Arial Narrow Italic.ttf
#
# ▶ 字体族: Arial Rounded MT Bold
#   - 文件: /System/Library/Fonts/Supplemental/Arial Rounded Bold.ttf
#
# ▶ 字体族: Arial Unicode MS
#   - 文件: /System/Library/Fonts/Supplemental/Arial Unicode.ttf
#   - 文件: /Library/Fonts/Arial Unicode.ttf
#
# ▶ 字体族: Athelas
#   - 文件: /System/Library/Fonts/Supplemental/Athelas.ttc
#
# ▶ 字体族: Avenir
#   - 文件: /System/Library/Fonts/Avenir.ttc
#
# ▶ 字体族: Avenir Next
#   - 文件: /System/Library/Fonts/Avenir Next.ttc
#
# ▶ 字体族: Avenir Next Condensed
#   - 文件: /System/Library/Fonts/Avenir Next Condensed.ttc
#
# ▶ 字体族: Ayuthaya
#   - 文件: /System/Library/Fonts/Supplemental/Ayuthaya.ttf
#
# ▶ 字体族: BIZ UDGothic
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/d7d512f49387f96799ae9271c7fa8f8e9fef05d1.asset/AssetData/BIZ_UDGothic.ttc
#
# ▶ 字体族: BIZ UDMincho
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/e617c1b15920c6ee2d047ed8724de08521ce5c9a.asset/AssetData/BIZ_UDMincho-regular.ttf
#
# ▶ 字体族: BM Dohyeon
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/e71ea5469e5f2039223f22203ee8b9186524afd3.asset/AssetData/BMDoHyeon-Regular.otf
#
# ▶ 字体族: BM Hanna 11yrs Old
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/157acc4d862730d6d5beaa943546f80a71948c7b.asset/AssetData/BMHanna11yrs-Regular.otf
#
# ▶ 字体族: BM Hanna Air
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/12cc699be28fb04f3e3c4969a0378a87b920b174.asset/AssetData/BMHannaAir-Regular.otf
#
# ▶ 字体族: BM Hanna Pro
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/5f2614e7b55639e709d8578e16b324b3eb6eb065.asset/AssetData/BMHannaPro-Regular.otf
#
# ▶ 字体族: BM Jua
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/5b2f5f0b003344b2c67ce463e76d2485bb43d054.asset/AssetData/BMJua-Regular.otf
#
# ▶ 字体族: BM Kirang Haerang
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/cd59971ded42add9070aa2172265ba7fcf8d9327.asset/AssetData/BMKirangHaerang-Regular.otf
#
# ▶ 字体族: BM Yeonsung
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/9bcdfd464af84ab30592d781f4a82f44f548239c.asset/AssetData/BMYeongSung-Regular.otf
#
# ▶ 字体族: Baghdad
#   - 文件: /System/Library/Fonts/Supplemental/Baghdad.ttc
#
# ▶ 字体族: Bangla MN
#   - 文件: /System/Library/Fonts/Supplemental/Bangla MN.ttc
#
# ▶ 字体族: Bangla Sangam MN
#   - 文件: /System/Library/Fonts/Supplemental/Bangla Sangam MN.ttc
#
# ▶ 字体族: Baoli SC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/9d5450ee93f17da1eacfa01b5e7b598f9e2dda2b.asset/AssetData/Baoli.ttc
#
# ▶ 字体族: Baskerville
#   - 文件: /System/Library/Fonts/Supplemental/Baskerville.ttc
#
# ▶ 字体族: Beirut
#   - 文件: /System/Library/Fonts/Supplemental/Beirut.ttc
#
# ▶ 字体族: BiauKaiHK
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/584ea2a48d14147049c2f9eaee147fe5a1f279ac.asset/AssetData/BiauKai.ttc
#
# ▶ 字体族: Big Caslon
#   - 文件: /System/Library/Fonts/Supplemental/BigCaslon.ttf
#
# ▶ 字体族: Bodoni 72
#   - 文件: /System/Library/Fonts/Supplemental/Bodoni 72.ttc
#
# ▶ 字体族: Bodoni 72 Oldstyle
#   - 文件: /System/Library/Fonts/Supplemental/Bodoni 72 OS.ttc
#
# ▶ 字体族: Bodoni 72 Smallcaps
#   - 文件: /System/Library/Fonts/Supplemental/Bodoni 72 Smallcaps Book.ttf
#
# ▶ 字体族: Bodoni Ornaments
#   - 文件: /System/Library/Fonts/Supplemental/Bodoni Ornaments.ttf
#
# ▶ 字体族: Bradley Hand
#   - 文件: /System/Library/Fonts/Supplemental/Bradley Hand Bold.ttf
#
# ▶ 字体族: Brush Script MT
#   - 文件: /System/Library/Fonts/Supplemental/Brush Script.ttf
#
# ▶ 字体族: Chalkboard
#   - 文件: /System/Library/Fonts/Supplemental/Chalkboard.ttc
#
# ▶ 字体族: Chalkboard SE
#   - 文件: /System/Library/Fonts/Supplemental/ChalkboardSE.ttc
#
# ▶ 字体族: Chalkduster
#   - 文件: /System/Library/Fonts/Supplemental/Chalkduster.ttf
#
# ▶ 字体族: Charter
#   - 文件: /System/Library/Fonts/Supplemental/Charter.ttc
#
# ▶ 字体族: Cochin
#   - 文件: /System/Library/Fonts/Supplemental/Cochin.ttc
#
# ▶ 字体族: Comic Sans MS
#   - 文件: /System/Library/Fonts/Supplemental/Comic Sans MS Bold.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Comic Sans MS.ttf
#
# ▶ 字体族: Copperplate
#   - 文件: /System/Library/Fonts/Supplemental/Copperplate.ttc
#
# ▶ 字体族: Corsiva Hebrew
#   - 文件: /System/Library/Fonts/Supplemental/Corsiva.ttc
#
# ▶ 字体族: Courier
#   - 文件: /System/Library/Fonts/Courier.ttc
#
# ▶ 字体族: Courier New
#   - 文件: /System/Library/Fonts/Supplemental/Courier New Bold.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Courier New Italic.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Courier New.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Courier New Bold Italic.ttf
#
# ▶ 字体族: DIN Alternate
#   - 文件: /System/Library/Fonts/Supplemental/DIN Alternate Bold.ttf
#
# ▶ 字体族: DIN Condensed
#   - 文件: /System/Library/Fonts/Supplemental/DIN Condensed Bold.ttf
#
# ▶ 字体族: Damascus
#   - 文件: /System/Library/Fonts/Supplemental/Damascus.ttc
#
# ▶ 字体族: DecoType Naskh
#   - 文件: /System/Library/Fonts/Supplemental/DecoTypeNaskh.ttc
#
# ▶ 字体族: DejaVu Sans
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf
#
# ▶ 字体族: DejaVu Sans Display
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf
#
# ▶ 字体族: DejaVu Sans Mono
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf
#
# ▶ 字体族: DejaVu Serif
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf
#
# ▶ 字体族: DejaVu Serif Display
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf
#
# ▶ 字体族: Devanagari MT
#   - 文件: /System/Library/Fonts/Supplemental/DevanagariMT.ttc
#
# ▶ 字体族: Devanagari Sangam MN
#   - 文件: /System/Library/Fonts/Supplemental/Devanagari Sangam MN.ttc
#
# ▶ 字体族: Didot
#   - 文件: /System/Library/Fonts/Supplemental/Didot.ttc
#
# ▶ 字体族: Diwan Kufi
#   - 文件: /System/Library/Fonts/Supplemental/Diwan Kufi.ttc
#
# ▶ 字体族: Diwan Thuluth
#   - 文件: /System/Library/Fonts/Supplemental/Diwan Thuluth.ttf
#
# ▶ 字体族: Euphemia UCAS
#   - 文件: /System/Library/Fonts/Supplemental/EuphemiaCAS.ttc
#
# ▶ 字体族: Farah
#   - 文件: /System/Library/Fonts/Supplemental/Farah.ttc
#
# ▶ 字体族: Farisi
#   - 文件: /System/Library/Fonts/Supplemental/Farisi.ttf
#
# ▶ 字体族: Fira Code
#   - 文件: /Users/zhangchao/Library/Fonts/FiraCode-Light.ttf
#   - 文件: /Users/zhangchao/Library/Fonts/FiraCode-Regular.ttf
#   - 文件: /Users/zhangchao/Library/Fonts/FiraCode-Bold.ttf
#   - 文件: /Users/zhangchao/Library/Fonts/FiraCode-SemiBold.ttf
#   - 文件: /Users/zhangchao/Library/Fonts/FiraCode-Medium.ttf
#   ... (等 1 个文件)
#
# ▶ 字体族: Futura
#   - 文件: /System/Library/Fonts/Supplemental/Futura.ttc
#
# ▶ 字体族: Galvji
#   - 文件: /System/Library/Fonts/Supplemental/Galvji.ttc
#
# ▶ 字体族: Geeza Pro
#   - 文件: /System/Library/Fonts/GeezaPro.ttc
#
# ▶ 字体族: Geneva
#   - 文件: /System/Library/Fonts/Geneva.ttf
#
# ▶ 字体族: Georgia
#   - 文件: /System/Library/Fonts/Supplemental/Georgia Bold Italic.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Georgia.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Georgia Italic.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Georgia Bold.ttf
#
# ▶ 字体族: Gill Sans
#   - 文件: /System/Library/Fonts/Supplemental/GillSans.ttc
#
# ▶ 字体族: Gujarati MT
#   - 文件: /System/Library/Fonts/Supplemental/GujaratiMT.ttc
#
# ▶ 字体族: Gujarati Sangam MN
#   - 文件: /System/Library/Fonts/Supplemental/Gujarati Sangam MN.ttc
#
# ▶ 字体族: GungSeo
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/f879347736afb6e4e0880bcede9df92492c0f040.asset/AssetData/Gungseouche.ttf
#
# ▶ 字体族: Gurmukhi MN
#   - 文件: /System/Library/Fonts/Supplemental/Gurmukhi MN.ttc
#
# ▶ 字体族: Gurmukhi MT
#   - 文件: /System/Library/Fonts/Supplemental/Gurmukhi.ttf
#
# ▶ 字体族: Gurmukhi Sangam MN
#   - 文件: /System/Library/Fonts/Supplemental/Gurmukhi Sangam MN.ttc
#
# ▶ 字体族: Hannotate SC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/8dc7805506cc9f233dcc19aabf593196842a47ae.asset/AssetData/Hannotate.ttc
#
# ▶ 字体族: HanziPen SC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/9fdda46cbe802833590494a09b2787378340c597.asset/AssetData/Hanzipen.ttc
#
# ▶ 字体族: HeadLineA
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/de4b2bad515a67ab2d11e39fd896b1e189252a43.asset/AssetData/HeadlineA.ttf
#
# ▶ 字体族: Hei
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/62032b9b64a0e3a9121c50aeb2ed794e3e2c201f.asset/AssetData/Hei.ttf
#
# ▶ 字体族: Heiti TC
#   - 文件: /System/Library/Fonts/STHeiti Medium.ttc
#   - 文件: /System/Library/Fonts/STHeiti Light.ttc
#
# ▶ 字体族: Helvetica
#   - 文件: /System/Library/Fonts/Helvetica.ttc
#
# ▶ 字体族: Helvetica Neue
#   - 文件: /System/Library/Fonts/HelveticaNeue.ttc
#
# ▶ 字体族: Herculanum
#   - 文件: /System/Library/Fonts/Supplemental/Herculanum.ttf
#
# ▶ 字体族: Hiragino Maru Gothic Pro
#   - 文件: /System/Library/Fonts/ヒラギノ丸ゴ ProN W4.ttc
#
# ▶ 字体族: Hiragino Mincho ProN
#   - 文件: /System/Library/Fonts/ヒラギノ明朝 ProN.ttc
#
# ▶ 字体族: Hiragino Sans
#   - 文件: /System/Library/Fonts/ヒラギノ角ゴシック W7.ttc
#   - 文件: /System/Library/Fonts/ヒラギノ角ゴシック W4.ttc
#   - 文件: /System/Library/Fonts/ヒラギノ角ゴシック W8.ttc
#   - 文件: /System/Library/Fonts/ヒラギノ角ゴシック W0.ttc
#   - 文件: /System/Library/Fonts/ヒラギノ角ゴシック W2.ttc
#   ... (等 5 个文件)
#
# ▶ 字体族: Hiragino Sans CNS
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/32d11e548996658757774d88f9220993653017ea.asset/AssetData/Hiragino_Sans_CNS.ttc
#
# ▶ 字体族: Hiragino Sans GB
#   - 文件: /System/Library/Fonts/Hiragino Sans GB.ttc
#
# ▶ 字体族: Hoefler Text
#   - 文件: /System/Library/Fonts/Supplemental/Hoefler Text Ornaments.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Hoefler Text.ttc
#
# ▶ 字体族: ITF Devanagari
#   - 文件: /System/Library/Fonts/Supplemental/ITFDevanagari.ttc
#
# ▶ 字体族: Impact
#   - 文件: /System/Library/Fonts/Supplemental/Impact.ttf
#
# ▶ 字体族: InaiMathi
#   - 文件: /System/Library/Fonts/Supplemental/InaiMathi-MN.ttc
#
# ▶ 字体族: Iowan Old Style
#   - 文件: /System/Library/Fonts/Supplemental/Iowan Old Style.ttc
#
# ▶ 字体族: Kai
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/28f00a24ba19995bab7249993e6e35d11011074a.asset/AssetData/Kai.ttf
#
# ▶ 字体族: Kailasa
#   - 文件: /System/Library/Fonts/Supplemental/Kailasa.ttc
#
# ▶ 字体族: Kaiti SC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/54a2ad3dac6cac875ad675d7d273dc425010a877.asset/AssetData/Kaiti.ttc
#
# ▶ 字体族: Kannada MN
#   - 文件: /System/Library/Fonts/Supplemental/Kannada MN.ttc
#
# ▶ 字体族: Kannada Sangam MN
#   - 文件: /System/Library/Fonts/Supplemental/Kannada Sangam MN.ttc
#
# ▶ 字体族: Kefa
#   - 文件: /System/Library/Fonts/Supplemental/Kefa.ttc
#
# ▶ 字体族: Khmer MN
#   - 文件: /System/Library/Fonts/Supplemental/Khmer MN.ttc
#
# ▶ 字体族: Khmer Sangam MN
#   - 文件: /System/Library/Fonts/Supplemental/Khmer Sangam MN.ttf
#
# ▶ 字体族: Klee
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/f110a45f1759f86c645cfd2f47baba57aa50056e.asset/AssetData/Klee.ttc
#
# ▶ 字体族: Kohinoor Bangla
#   - 文件: /System/Library/Fonts/KohinoorBangla.ttc
#
# ▶ 字体族: Kohinoor Devanagari
#   - 文件: /System/Library/Fonts/Kohinoor.ttc
#
# ▶ 字体族: Kohinoor Gujarati
#   - 文件: /System/Library/Fonts/KohinoorGujarati.ttc
#
# ▶ 字体族: Kohinoor Telugu
#   - 文件: /System/Library/Fonts/KohinoorTelugu.ttc
#
# ▶ 字体族: Kokonor
#   - 文件: /System/Library/Fonts/Supplemental/Kokonor.ttf
#
# ▶ 字体族: Krungthep
#   - 文件: /System/Library/Fonts/Supplemental/Krungthep.ttf
#
# ▶ 字体族: KufiStandardGK
#   - 文件: /System/Library/Fonts/Supplemental/KufiStandardGK.ttc
#
# ▶ 字体族: Lantinghei SC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/f7f6b250e97c182e68ac53a2b359ec44548878b9.asset/AssetData/Lantinghei.ttc
#
# ▶ 字体族: Lao MN
#   - 文件: /System/Library/Fonts/Supplemental/Lao MN.ttc
#
# ▶ 字体族: Lao Sangam MN
#   - 文件: /System/Library/Fonts/Supplemental/Lao Sangam MN.ttf
#
# ▶ 字体族: LiHei Pro
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/3a9dbc8ddc8b85f43055a28fb5d551e905d43de2.asset/AssetData/LiHeiPro.ttf
#
# ▶ 字体族: LiSong Pro
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/5a3fc034b64879656271c040cab38b65d4ea6548.asset/AssetData/LiSongPro.ttf
#
# ▶ 字体族: Libian SC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/7278ac2566252649b05c5a2b07c7d45be59f47c5.asset/AssetData/Libian.ttc
#
# ▶ 字体族: LingWai SC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/e2c331b942cb338404a160a97a7cd6e8a31428e8.asset/AssetData/LingWaiSC-Medium.otf
#
# ▶ 字体族: LingWai TC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/b8cf53b3591d6062cd536ba5129454cba899a078.asset/AssetData/LingWaiTC-Medium.otf
#
# ▶ 字体族: Lucida Grande
#   - 文件: /System/Library/Fonts/LucidaGrande.ttc
#
# ▶ 字体族: Luminari
#   - 文件: /System/Library/Fonts/Supplemental/Luminari.ttf
#
# ▶ 字体族: Malayalam MN
#   - 文件: /System/Library/Fonts/Supplemental/Malayalam MN.ttc
#
# ▶ 字体族: Malayalam Sangam MN
#   - 文件: /System/Library/Fonts/Supplemental/Malayalam Sangam MN.ttc
#
# ▶ 字体族: Maple Mono
#   - 文件: /Users/zhangchao/Library/Fonts/MapleMono-ExtraBold.ttf
#   - 文件: /Users/zhangchao/Library/Fonts/MapleMono-Medium.ttf
#   - 文件: /Users/zhangchao/Library/Fonts/MapleMono-Light.ttf
#   - 文件: /Users/zhangchao/Library/Fonts/MapleMono-ExtraLightItalic.ttf
#   - 文件: /Users/zhangchao/Library/Fonts/MapleMono-Bold.ttf
#   ... (等 11 个文件)
#
# ▶ 字体族: Marion
#   - 文件: /System/Library/Fonts/Supplemental/Marion.ttc
#
# ▶ 字体族: Marker Felt
#   - 文件: /System/Library/Fonts/MarkerFelt.ttc
#
# ▶ 字体族: Menlo
#   - 文件: /System/Library/Fonts/Menlo.ttc
#
# ▶ 字体族: Microsoft Sans Serif
#   - 文件: /System/Library/Fonts/Supplemental/Microsoft Sans Serif.ttf
#
# ▶ 字体族: Mishafi
#   - 文件: /System/Library/Fonts/Supplemental/Mishafi.ttf
#
# ▶ 字体族: Mishafi Gold
#   - 文件: /System/Library/Fonts/Supplemental/Mishafi Gold.ttf
#
# ▶ 字体族: Monaco
#   - 文件: /System/Library/Fonts/Monaco.ttf
#
# ▶ 字体族: Mshtakan
#   - 文件: /System/Library/Fonts/Supplemental/Mshtakan.ttc
#
# ▶ 字体族: Mukta Mahee
#   - 文件: /System/Library/Fonts/MuktaMahee.ttc
#
# ▶ 字体族: Muna
#   - 文件: /System/Library/Fonts/Supplemental/Muna.ttc
#
# ▶ 字体族: Myanmar MN
#   - 文件: /System/Library/Fonts/Supplemental/Myanmar MN.ttc
#
# ▶ 字体族: Myanmar Sangam MN
#   - 文件: /System/Library/Fonts/Supplemental/Myanmar Sangam MN.ttc
#
# ▶ 字体族: Nadeem
#   - 文件: /System/Library/Fonts/Supplemental/Nadeem.ttc
#
# ▶ 字体族: Nanum Brush Script
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/6f4c91728bb824d6960725ec479c355eab7eeba8.asset/AssetData/NanumScript.ttc
#
# ▶ 字体族: Nanum Gothic
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/bad9b4bf17cf1669dde54184ba4431c22dcad27b.asset/AssetData/NanumGothic.ttc
#
# ▶ 字体族: Nanum Myeongjo
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/70816a43827731d40efe234b94feba96db91024f.asset/AssetData/NanumMyeongjo.ttc
#
# ▶ 字体族: New Peninim MT
#   - 文件: /System/Library/Fonts/Supplemental/NewPeninimMT.ttc
#
# ▶ 字体族: Noteworthy
#   - 文件: /System/Library/Fonts/Noteworthy.ttc
#
# ▶ 字体族: Noto Nastaliq Urdu
#   - 文件: /System/Library/Fonts/NotoNastaliq.ttc
#
# ▶ 字体族: Noto Sans Adlam
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansAdlam-Regular.ttf
#
# ▶ 字体族: Noto Sans Armenian
#   - 文件: /System/Library/Fonts/NotoSansArmenian.ttc
#
# ▶ 字体族: Noto Sans Avestan
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansAvestan-Regular.ttf
#
# ▶ 字体族: Noto Sans Bamum
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansBamum-Regular.ttf
#
# ▶ 字体族: Noto Sans Bassa Vah
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansBassaVah-Regular.ttf
#
# ▶ 字体族: Noto Sans Batak
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansBatak-Regular.ttf
#
# ▶ 字体族: Noto Sans Bhaiksuki
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansBhaiksuki-Regular.ttf
#
# ▶ 字体族: Noto Sans Brahmi
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansBrahmi-Regular.ttf
#
# ▶ 字体族: Noto Sans Buginese
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansBuginese-Regular.ttf
#
# ▶ 字体族: Noto Sans Buhid
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansBuhid-Regular.ttf
#
# ▶ 字体族: Noto Sans Canadian Aboriginal
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansCanadianAboriginal-Regular.otf
#
# ▶ 字体族: Noto Sans Carian
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansCarian-Regular.ttf
#
# ▶ 字体族: Noto Sans Caucasian Albanian
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansCaucasianAlbanian-Regular.ttf
#
# ▶ 字体族: Noto Sans Chakma
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansChakma-Regular.ttf
#
# ▶ 字体族: Noto Sans Cham
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansCham-Regular.ttf
#
# ▶ 字体族: Noto Sans Coptic
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansCoptic-Regular.ttf
#
# ▶ 字体族: Noto Sans Cuneiform
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansCuneiform-Regular.ttf
#
# ▶ 字体族: Noto Sans Cypriot
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansCypriot-Regular.ttf
#
# ▶ 字体族: Noto Sans Duployan
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansDuployan-Regular.ttf
#
# ▶ 字体族: Noto Sans Egyptian Hieroglyphs
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansEgyptianHieroglyphs-Regular.ttf
#
# ▶ 字体族: Noto Sans Elbasan
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansElbasan-Regular.ttf
#
# ▶ 字体族: Noto Sans Glagolitic
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansGlagolitic-Regular.ttf
#
# ▶ 字体族: Noto Sans Gothic
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansGothic-Regular.ttf
#
# ▶ 字体族: Noto Sans Gunjala Gondi
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansGunjalaGondi-Regular.otf
#
# ▶ 字体族: Noto Sans Hanifi Rohingya
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansHanifiRohingya-Regular.ttf
#
# ▶ 字体族: Noto Sans Hanunoo
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansHanunoo-Regular.ttf
#
# ▶ 字体族: Noto Sans Hatran
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansHatran-Regular.ttf
#
# ▶ 字体族: Noto Sans Imperial Aramaic
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansImperialAramaic-Regular.ttf
#
# ▶ 字体族: Noto Sans Inscriptional Pahlavi
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansInscriptionalPahlavi-Regular.ttf
#
# ▶ 字体族: Noto Sans Inscriptional Parthian
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansInscriptionalParthian-Regular.ttf
#
# ▶ 字体族: Noto Sans Javanese
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansJavanese-Regular.otf
#
# ▶ 字体族: Noto Sans Kaithi
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansKaithi-Regular.ttf
#
# ▶ 字体族: Noto Sans Kannada
#   - 文件: /System/Library/Fonts/NotoSansKannada.ttc
#
# ▶ 字体族: Noto Sans Kayah Li
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansKayahLi-Regular.ttf
#
# ▶ 字体族: Noto Sans Kharoshthi
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansKharoshthi-Regular.ttf
#
# ▶ 字体族: Noto Sans Khojki
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansKhojki-Regular.ttf
#
# ▶ 字体族: Noto Sans Khudawadi
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansKhudawadi-Regular.ttf
#
# ▶ 字体族: Noto Sans Lepcha
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansLepcha-Regular.ttf
#
# ▶ 字体族: Noto Sans Limbu
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansLimbu-Regular.ttf
#
# ▶ 字体族: Noto Sans Linear A
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansLinearA-Regular.ttf
#
# ▶ 字体族: Noto Sans Linear B
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansLinearB-Regular.ttf
#
# ▶ 字体族: Noto Sans Lisu
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansLisu-Regular.ttf
#
# ▶ 字体族: Noto Sans Lycian
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansLycian-Regular.ttf
#
# ▶ 字体族: Noto Sans Lydian
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansLydian-Regular.ttf
#
# ▶ 字体族: Noto Sans Mahajani
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansMahajani-Regular.ttf
#
# ▶ 字体族: Noto Sans Mandaic
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansMandaic-Regular.ttf
#
# ▶ 字体族: Noto Sans Manichaean
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansManichaean-Regular.ttf
#
# ▶ 字体族: Noto Sans Marchen
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansMarchen-Regular.ttf
#
# ▶ 字体族: Noto Sans Masaram Gondi
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansMasaramGondi-Regular.otf
#
# ▶ 字体族: Noto Sans Meetei Mayek
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansMeeteiMayek-Regular.ttf
#
# ▶ 字体族: Noto Sans Mende Kikakui
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansMendeKikakui-Regular.ttf
#
# ▶ 字体族: Noto Sans Meroitic
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansMeroitic-Regular.ttf
#
# ▶ 字体族: Noto Sans Miao
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansMiao-Regular.ttf
#
# ▶ 字体族: Noto Sans Modi
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansModi-Regular.ttf
#
# ▶ 字体族: Noto Sans Mongolian
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansMongolian-Regular.ttf
#
# ▶ 字体族: Noto Sans Mro
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansMro-Regular.ttf
#
# ▶ 字体族: Noto Sans Multani
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansMultani-Regular.ttf
#
# ▶ 字体族: Noto Sans Myanmar
#   - 文件: /System/Library/Fonts/NotoSansMyanmar.ttc
#
# ▶ 字体族: Noto Sans NKo
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansNKo-Regular.ttf
#
# ▶ 字体族: Noto Sans Nabataean
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansNabataean-Regular.ttf
#
# ▶ 字体族: Noto Sans New Tai Lue
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansNewTaiLue-Regular.ttf
#
# ▶ 字体族: Noto Sans Newa
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansNewa-Regular.ttf
#
# ▶ 字体族: Noto Sans Ol Chiki
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansOlChiki-Regular.ttf
#
# ▶ 字体族: Noto Sans Old Hungarian
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansOldHungarian-Regular.ttf
#
# ▶ 字体族: Noto Sans Old Italic
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansOldItalic-Regular.ttf
#
# ▶ 字体族: Noto Sans Old North Arabian
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansOldNorthArabian-Regular.ttf
#
# ▶ 字体族: Noto Sans Old Permic
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansOldPermic-Regular.ttf
#
# ▶ 字体族: Noto Sans Old Persian
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansOldPersian-Regular.ttf
#
# ▶ 字体族: Noto Sans Old South Arabian
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansOldSouthArabian-Regular.ttf
#
# ▶ 字体族: Noto Sans Old Turkic
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansOldTurkic-Regular.ttf
#
# ▶ 字体族: Noto Sans Oriya
#   - 文件: /System/Library/Fonts/NotoSansOriya.ttc
#
# ▶ 字体族: Noto Sans Osage
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansOsage-Regular.ttf
#
# ▶ 字体族: Noto Sans Osmanya
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansOsmanya-Regular.ttf
#
# ▶ 字体族: Noto Sans Pahawh Hmong
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansPahawhHmong-Regular.ttf
#
# ▶ 字体族: Noto Sans Palmyrene
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansPalmyrene-Regular.ttf
#
# ▶ 字体族: Noto Sans Pau Cin Hau
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansPauCinHau-Regular.ttf
#
# ▶ 字体族: Noto Sans PhagsPa
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansPhagsPa-Regular.ttf
#
# ▶ 字体族: Noto Sans Phoenician
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansPhoenician-Regular.ttf
#
# ▶ 字体族: Noto Sans Psalter Pahlavi
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansPsalterPahlavi-Regular.ttf
#
# ▶ 字体族: Noto Sans Rejang
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansRejang-Regular.ttf
#
# ▶ 字体族: Noto Sans Samaritan
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansSamaritan-Regular.ttf
#
# ▶ 字体族: Noto Sans Saurashtra
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansSaurashtra-Regular.ttf
#
# ▶ 字体族: Noto Sans Sharada
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansSharada-Regular.ttf
#
# ▶ 字体族: Noto Sans Siddham
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansSiddham-Regular.otf
#
# ▶ 字体族: Noto Sans Sora Sompeng
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansSoraSompeng-Regular.ttf
#
# ▶ 字体族: Noto Sans Sundanese
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansSundanese-Regular.ttf
#
# ▶ 字体族: Noto Sans Syloti Nagri
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansSylotiNagri-Regular.ttf
#
# ▶ 字体族: Noto Sans Syriac
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansSyriac-Regular.ttf
#
# ▶ 字体族: Noto Sans Tagalog
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansTagalog-Regular.ttf
#
# ▶ 字体族: Noto Sans Tagbanwa
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansTagbanwa-Regular.ttf
#
# ▶ 字体族: Noto Sans Tai Le
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansTaiLe-Regular.ttf
#
# ▶ 字体族: Noto Sans Tai Tham
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansTaiTham-Regular.ttf
#
# ▶ 字体族: Noto Sans Tai Viet
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansTaiViet-Regular.ttf
#
# ▶ 字体族: Noto Sans Takri
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansTakri-Regular.ttf
#
# ▶ 字体族: Noto Sans Thaana
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansThaana-Regular.ttf
#
# ▶ 字体族: Noto Sans Tifinagh
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansTifinagh-Regular.otf
#
# ▶ 字体族: Noto Sans Tirhuta
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansTirhuta-Regular.ttf
#
# ▶ 字体族: Noto Sans Ugaritic
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansUgaritic-Regular.ttf
#
# ▶ 字体族: Noto Sans Vai
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansVai-Regular.ttf
#
# ▶ 字体族: Noto Sans Wancho
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansWancho-Regular.ttf
#
# ▶ 字体族: Noto Sans Warang Citi
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansWarangCiti-Regular.ttf
#
# ▶ 字体族: Noto Sans Yi
#   - 文件: /System/Library/Fonts/Supplemental/NotoSansYi-Regular.ttf
#
# ▶ 字体族: Noto Serif Ahom
#   - 文件: /System/Library/Fonts/Supplemental/NotoSerifAhom-Regular.ttf
#
# ▶ 字体族: Noto Serif Balinese
#   - 文件: /System/Library/Fonts/Supplemental/NotoSerifBalinese-Regular.ttf
#
# ▶ 字体族: Noto Serif Hmong Nyiakeng
#   - 文件: /System/Library/Fonts/Supplemental/NotoSerifNyiakengPuachueHmong-Regular.ttf
#
# ▶ 字体族: Noto Serif Myanmar
#   - 文件: /System/Library/Fonts/NotoSerifMyanmar.ttc
#
# ▶ 字体族: Noto Serif Yezidi
#   - 文件: /System/Library/Fonts/Supplemental/NotoSerifYezidi-Regular.otf
#
# ▶ 字体族: OPPO Sans 4.0
#   - 文件: /Users/zhangchao/Library/Fonts/OPPO Sans 4.0.ttf
#
# ▶ 字体族: Optima
#   - 文件: /System/Library/Fonts/Optima.ttc
#
# ▶ 字体族: Oriya MN
#   - 文件: /System/Library/Fonts/Supplemental/Oriya MN.ttc
#
# ▶ 字体族: Oriya Sangam MN
#   - 文件: /System/Library/Fonts/Supplemental/Oriya Sangam MN.ttc
#
# ▶ 字体族: Osaka
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/a3f9a9e35bdf3babe03b2fd162051306fad439d6.asset/AssetData/Osaka.ttf
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/0818d874bf1d0e24a1fe62e79f407717792c5ee1.asset/AssetData/OsakaMono.ttf
#
# ▶ 字体族: PCMyungjo
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/c2cf5e684236b5395fd48d6ccf0e3b3191ce83a0.asset/AssetData/PCmyoungjo.ttf
#
# ▶ 字体族: PSL Ornanong Pro
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/ad8c3bb76851adc11dc4772c1a7a00caf83e3037.asset/AssetData/Ornanong.ttc
#
# ▶ 字体族: PT Mono
#   - 文件: /System/Library/Fonts/Supplemental/PTMono.ttc
#
# ▶ 字体族: PT Sans
#   - 文件: /System/Library/Fonts/Supplemental/PTSans.ttc
#
# ▶ 字体族: PT Serif
#   - 文件: /System/Library/Fonts/Supplemental/PTSerif.ttc
#
# ▶ 字体族: PT Serif Caption
#   - 文件: /System/Library/Fonts/Supplemental/PTSerifCaption.ttc
#
# ▶ 字体族: Palatino
#   - 文件: /System/Library/Fonts/Palatino.ttc
#
# ▶ 字体族: Papyrus
#   - 文件: /System/Library/Fonts/Supplemental/Papyrus.ttc
#
# ▶ 字体族: Party LET
#   - 文件: /System/Library/Fonts/Supplemental/PartyLET-plain.ttf
#
# ▶ 字体族: Phosphate
#   - 文件: /System/Library/Fonts/Supplemental/Phosphate.ttc
#
# ▶ 字体族: PilGi
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/7ca27bc02dd7660f9dacd69df96d24639b96e080.asset/AssetData/Pilgiche.ttf
#
# ▶ 字体族: PingFang HK
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/3419f2a427639ad8c8e139149a287865a90fa17e.asset/AssetData/PingFang.ttc
#
# ▶ 字体族: Plantagenet Cherokee
#   - 文件: /System/Library/Fonts/Supplemental/PlantagenetCherokee.ttf
#
# ▶ 字体族: Raanana
#   - 文件: /System/Library/Fonts/Supplemental/Raanana.ttc
#
# ▶ 字体族: Rockwell
#   - 文件: /System/Library/Fonts/Supplemental/Rockwell.ttc
#
# ▶ 字体族: SF Compact
#   - 文件: /Library/Fonts/SF-Compact-Italic.ttf
#   - 文件: /Library/Fonts/SF-Compact.ttf
#
# ▶ 字体族: SF Compact Display
#   - 文件: /Library/Fonts/SF-Compact-Display-Semibold.otf
#   - 文件: /Library/Fonts/SF-Compact-Display-Regular.otf
#   - 文件: /Library/Fonts/SF-Compact-Display-Medium.otf
#   - 文件: /Library/Fonts/SF-Compact-Display-Ultralight.otf
#   - 文件: /Library/Fonts/SF-Compact-Display-Black.otf
#   ... (等 4 个文件)
#
# ▶ 字体族: SF Compact Rounded
#   - 文件: /Library/Fonts/SF-Compact-Rounded-Thin.otf
#   - 文件: /Library/Fonts/SF-Compact-Rounded-Black.otf
#   - 文件: /Library/Fonts/SF-Compact-Rounded-Medium.otf
#   - 文件: /Library/Fonts/SF-Compact-Rounded-Ultralight.otf
#   - 文件: /Library/Fonts/SF-Compact-Rounded-Heavy.otf
#   ... (等 4 个文件)
#
# ▶ 字体族: SF Compact Text
#   - 文件: /Library/Fonts/SF-Compact-Text-Ultralight.otf
#   - 文件: /Library/Fonts/SF-Compact-Text-RegularItalic.otf
#   - 文件: /Library/Fonts/SF-Compact-Text-Light.otf
#   - 文件: /Library/Fonts/SF-Compact-Text-Black.otf
#   - 文件: /Library/Fonts/SF-Compact-Text-MediumItalic.otf
#   ... (等 13 个文件)
#
# ▶ 字体族: SF Pro
#   - 文件: /Library/Fonts/SF-Pro-Italic.ttf
#   - 文件: /Library/Fonts/SF-Pro.ttf
#
# ▶ 字体族: SF Pro Display
#   - 文件: /Library/Fonts/SF-Pro-Display-Black.otf
#   - 文件: /Library/Fonts/SF-Pro-Display-Light.otf
#   - 文件: /Library/Fonts/SF-Pro-Display-UltralightItalic.otf
#   - 文件: /Library/Fonts/SF-Pro-Display-Ultralight.otf
#   - 文件: /Library/Fonts/SF-Pro-Display-SemiboldItalic.otf
#   ... (等 13 个文件)
#
# ▶ 字体族: SF Pro Rounded
#   - 文件: /Library/Fonts/SF-Pro-Rounded-Ultralight.otf
#   - 文件: /Library/Fonts/SF-Pro-Rounded-Thin.otf
#   - 文件: /Library/Fonts/SF-Pro-Rounded-Medium.otf
#   - 文件: /Library/Fonts/SF-Pro-Rounded-Bold.otf
#   - 文件: /Library/Fonts/SF-Pro-Rounded-Regular.otf
#   ... (等 4 个文件)
#
# ▶ 字体族: SF Pro Text
#   - 文件: /Library/Fonts/SF-Pro-Text-Black.otf
#   - 文件: /Library/Fonts/SF-Pro-Text-HeavyItalic.otf
#   - 文件: /Library/Fonts/SF-Pro-Text-Thin.otf
#   - 文件: /Library/Fonts/SF-Pro-Text-Semibold.otf
#   - 文件: /Library/Fonts/SF-Pro-Text-LightItalic.otf
#   ... (等 13 个文件)
#
# ▶ 字体族: STFangsong
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/1821952872c81043711aab6910052b65da8edf2c.asset/AssetData/STFANGSO.ttf
#
# ▶ 字体族: STHeiti
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/eb257c12d1a51c8c661b89f30eec56cacf9b8987.asset/AssetData/STHEITI.ttf
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/f0706a236683628e16427c6569e441423faaaa93.asset/AssetData/STXIHEI.ttf
#
# ▶ 字体族: STIX Two Math
#   - 文件: /System/Library/Fonts/Supplemental/STIXTwoMath.otf
#
# ▶ 字体族: STIX Two Text
#   - 文件: /System/Library/Fonts/Supplemental/STIXTwoText.ttf
#   - 文件: /System/Library/Fonts/Supplemental/STIXTwoText-Italic.ttf
#
# ▶ 字体族: STIXGeneral
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf
#   - 文件: /System/Library/Fonts/Supplemental/STIXGeneral.otf
#   ... (等 3 个文件)
#
# ▶ 字体族: STIXIntegralsD
#   - 文件: /System/Library/Fonts/Supplemental/STIXIntDReg.otf
#   - 文件: /System/Library/Fonts/Supplemental/STIXIntDBol.otf
#
# ▶ 字体族: STIXIntegralsSm
#   - 文件: /System/Library/Fonts/Supplemental/STIXIntSmBol.otf
#   - 文件: /System/Library/Fonts/Supplemental/STIXIntSmReg.otf
#
# ▶ 字体族: STIXIntegralsUp
#   - 文件: /System/Library/Fonts/Supplemental/STIXIntUpReg.otf
#   - 文件: /System/Library/Fonts/Supplemental/STIXIntUpBol.otf
#
# ▶ 字体族: STIXIntegralsUpD
#   - 文件: /System/Library/Fonts/Supplemental/STIXIntUpDBol.otf
#   - 文件: /System/Library/Fonts/Supplemental/STIXIntUpDReg.otf
#
# ▶ 字体族: STIXIntegralsUpSm
#   - 文件: /System/Library/Fonts/Supplemental/STIXIntUpSmBol.otf
#   - 文件: /System/Library/Fonts/Supplemental/STIXIntUpSmReg.otf
#
# ▶ 字体族: STIXNonUnicode
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf
#   - 文件: /System/Library/Fonts/Supplemental/STIXNonUniBol.otf
#   ... (等 3 个文件)
#
# ▶ 字体族: STIXSizeFiveSym
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf
#   - 文件: /System/Library/Fonts/Supplemental/STIXSizFiveSymReg.otf
#
# ▶ 字体族: STIXSizeFourSym
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf
#   - 文件: /System/Library/Fonts/Supplemental/STIXSizFourSymReg.otf
#   - 文件: /System/Library/Fonts/Supplemental/STIXSizFourSymBol.otf
#
# ▶ 字体族: STIXSizeOneSym
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf
#   - 文件: /System/Library/Fonts/Supplemental/STIXSizOneSymBol.otf
#   - 文件: /System/Library/Fonts/Supplemental/STIXSizOneSymReg.otf
#
# ▶ 字体族: STIXSizeThreeSym
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf
#   - 文件: /System/Library/Fonts/Supplemental/STIXSizThreeSymReg.otf
#   - 文件: /System/Library/Fonts/Supplemental/STIXSizThreeSymBol.otf
#
# ▶ 字体族: STIXSizeTwoSym
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf
#   - 文件: /System/Library/Fonts/Supplemental/STIXSizTwoSymReg.otf
#   - 文件: /System/Library/Fonts/Supplemental/STIXSizTwoSymBol.otf
#
# ▶ 字体族: STIXVariants
#   - 文件: /System/Library/Fonts/Supplemental/STIXVarBol.otf
#   - 文件: /System/Library/Fonts/Supplemental/STIXVar.otf
#
# ▶ 字体族: Sana
#   - 文件: /System/Library/Fonts/Supplemental/Sana.ttc
#
# ▶ 字体族: Sathu
#   - 文件: /System/Library/Fonts/Supplemental/Sathu.ttf
#
# ▶ 字体族: Savoye LET
#   - 文件: /System/Library/Fonts/Supplemental/Savoye LET.ttc
#
# ▶ 字体族: Seravek
#   - 文件: /System/Library/Fonts/Supplemental/Seravek.ttc
#
# ▶ 字体族: Shree Devanagari 714
#   - 文件: /System/Library/Fonts/Supplemental/Shree714.ttc
#
# ▶ 字体族: SignPainter
#   - 文件: /System/Library/Fonts/Supplemental/SignPainter.ttc
#
# ▶ 字体族: Silom
#   - 文件: /System/Library/Fonts/Supplemental/Silom.ttf
#
# ▶ 字体族: SimSong
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/857d6c90171c328a4892c1492291d34e401d7f25.asset/AssetData/SimSong.ttc
#
# ▶ 字体族: Sinhala MN
#   - 文件: /System/Library/Fonts/Supplemental/Sinhala MN.ttc
#
# ▶ 字体族: Sinhala Sangam MN
#   - 文件: /System/Library/Fonts/Supplemental/Sinhala Sangam MN.ttc
#
# ▶ 字体族: Skia
#   - 文件: /System/Library/Fonts/Supplemental/Skia.ttf
#
# ▶ 字体族: Smiley Sans
#   - 文件: /Users/zhangchao/Library/Fonts/SmileySans-Oblique.ttf
#
# ▶ 字体族: Snell Roundhand
#   - 文件: /System/Library/Fonts/Supplemental/SnellRoundhand.ttc
#
# ▶ 字体族: Songti SC
#   - 文件: /System/Library/Fonts/Supplemental/Songti.ttc
#
# ▶ 字体族: Sukhumvit Set
#   - 文件: /System/Library/Fonts/Supplemental/SukhumvitSet.ttc
#
# ▶ 字体族: Superclarendon
#   - 文件: /System/Library/Fonts/Supplemental/SuperClarendon.ttc
#
# ▶ 字体族: Symbol
#   - 文件: /System/Library/Fonts/Symbol.ttf
#
# ▶ 字体族: System Font
#   - 文件: /System/Library/Fonts/SFNSItalic.ttf
#   - 文件: /System/Library/Fonts/SFNS.ttf
#
# ▶ 字体族: Tahoma
#   - 文件: /System/Library/Fonts/Supplemental/Tahoma.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Tahoma Bold.ttf
#
# ▶ 字体族: Tamil MN
#   - 文件: /System/Library/Fonts/Supplemental/Tamil MN.ttc
#
# ▶ 字体族: Tamil Sangam MN
#   - 文件: /System/Library/Fonts/Supplemental/Tamil Sangam MN.ttc
#
# ▶ 字体族: Telugu MN
#   - 文件: /System/Library/Fonts/Supplemental/Telugu MN.ttc
#
# ▶ 字体族: Telugu Sangam MN
#   - 文件: /System/Library/Fonts/Supplemental/Telugu Sangam MN.ttc
#
# ▶ 字体族: Thonburi
#   - 文件: /System/Library/Fonts/Supplemental/Thonburi.ttc
#
# ▶ 字体族: Times
#   - 文件: /System/Library/Fonts/Times.ttc
#
# ▶ 字体族: Times New Roman
#   - 文件: /System/Library/Fonts/Supplemental/Times New Roman.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Times New Roman Bold.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Times New Roman Bold Italic.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Times New Roman Italic.ttf
#
# ▶ 字体族: Toppan Bunkyu Gothic
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/0ab217c39c45c7c6acaddfa199fd32c55a7b4a19.asset/AssetData/ToppanBunkyuGothicPr6N.ttc
#
# ▶ 字体族: Toppan Bunkyu Midashi Gothic
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/938fc4f0524ec9f143f1b39a4e63ff9585298376.asset/AssetData/ToppanBunkyuMidashiGothicStdN-ExtraBold.otf
#
# ▶ 字体族: Toppan Bunkyu Midashi Mincho
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/40e56e4eafd8b4db78ffe316f64ac4bedba37b53.asset/AssetData/ToppanBunkyuMidashiMinchoStdN-ExtraBold.otf
#
# ▶ 字体族: Toppan Bunkyu Mincho
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/8739f5cf483d3b2f04cbb451d310b68f0cf880d0.asset/AssetData/ToppanBunkyuMinchoPr6N-Regular.otf
#
# ▶ 字体族: Trattatello
#   - 文件: /System/Library/Fonts/Supplemental/Trattatello.ttf
#
# ▶ 字体族: Trebuchet MS
#   - 文件: /System/Library/Fonts/Supplemental/Trebuchet MS Italic.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Trebuchet MS Bold.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Trebuchet MS Bold Italic.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Trebuchet MS.ttf
#
# ▶ 字体族: Tsukushi A Round Gothic
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/d9a8a6ae726910080d90232eaf0edb06da712758.asset/AssetData/TsukushiAMaruGothic.ttc
#
# ▶ 字体族: Tsukushi B Round Gothic
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/10b097deccb3c6126d986e24b1980031ff7399da.asset/AssetData/TsukushiBMaruGothic.ttc
#
# ▶ 字体族: Verdana
#   - 文件: /System/Library/Fonts/Supplemental/Verdana Bold Italic.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Verdana Italic.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Verdana Bold.ttf
#   - 文件: /System/Library/Fonts/Supplemental/Verdana.ttf
#
# ▶ 字体族: Waseem
#   - 文件: /System/Library/Fonts/Supplemental/Waseem.ttc
#
# ▶ 字体族: Wawati SC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/18189590ed3a5f46cef20ed4d1cec2611dca13ff.asset/AssetData/WawaSC-Regular.otf
#
# ▶ 字体族: Wawati TC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/3d7c99b85a518ffb479044c11185e47744b6448d.asset/AssetData/WawaTC-Regular.otf
#
# ▶ 字体族: Webdings
#   - 文件: /System/Library/Fonts/Supplemental/Webdings.ttf
#
# ▶ 字体族: Wingdings
#   - 文件: /System/Library/Fonts/Supplemental/Wingdings.ttf
#
# ▶ 字体族: Wingdings 2
#   - 文件: /System/Library/Fonts/Supplemental/Wingdings 2.ttf
#
# ▶ 字体族: Wingdings 3
#   - 文件: /System/Library/Fonts/Supplemental/Wingdings 3.ttf
#
# ▶ 字体族: Xingkai SC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/aa99d0b2bad7f797f38b49d46cde28fd4b58876e.asset/AssetData/Xingkai.ttc
#
# ▶ 字体族: YuGothic
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/54ef167d6c8e99a69a0d41ce252cc5995ba47580.asset/AssetData/YuGothic-Medium.otf
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/42062e40d643fdb5bb3fba917212352fb0690de0.asset/AssetData/YuGothic-Bold.otf
#
# ▶ 字体族: YuKyokasho Yoko
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/5b843781be7f58151ada774942a0eaa9ec79bd57.asset/AssetData/Kyokasho.ttc
#
# ▶ 字体族: YuMincho
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/e9a9a2d18358033875835a6228cb70ce84b7e47c.asset/AssetData/YuMincho.ttc
#
# ▶ 字体族: Yuanti SC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/b86e58f38fd21e9782e70a104676f1655e72ebab.asset/AssetData/Yuanti.ttc
#
# ▶ 字体族: Yuppy SC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/96af7ec9e88d5dae450d3162213f92a7b1129430.asset/AssetData/YuppySC-Regular.otf
#
# ▶ 字体族: Yuppy TC
#   - 文件: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/e28431125242b9a298de3296370abdab4a7e8666.asset/AssetData/YuppyTC-Regular.otf
#
# ▶ 字体族: Zapf Dingbats
#   - 文件: /System/Library/Fonts/ZapfDingbats.ttf
#
# ▶ 字体族: Zapfino
#   - 文件: /System/Library/Fonts/Supplemental/Zapfino.ttf
#
# ▶ 字体族: Zhuque Fangsong (technical preview)
#   - 文件: /Users/zhangchao/Library/Fonts/ZhuqueFangsong-Regular.ttf
#
# ▶ 字体族: cmb10
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#
# ▶ 字体族: cmex10
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf
#
# ▶ 字体族: cmmi10
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf
#
# ▶ 字体族: cmr10
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf
#
# ▶ 字体族: cmss10
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf
#
# ▶ 字体族: cmsy10
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf
#
# ▶ 字体族: cmtt10
#   - 文件: /Users/zhangchao/Documents/Code/github/chromasky-toolkit/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf
#
# ======================================================================
# >>> 扫描结束。
# >>> 请从此列表中寻找您系统上安装的中文字体，例如：
#     - Windows: 'SimSun', 'SimHei', 'Microsoft YaHei', 'DengXian'
#     - macOS: 'PingFang SC', 'Hiragino Sans GB', 'STHeiti'
#     - Linux: 'Noto Sans CJK SC', 'WenQuanYi Micro Hei'
# ======================================================================
